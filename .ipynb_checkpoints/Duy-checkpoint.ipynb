# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import preprocessing 
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.metrics import precision_score, recall_score, confusion_matrix, classification_report, accuracy_score, f1_score
from sklearn import metrics
from sklearn.metrics import roc_curve, auc, roc_auc_score

# %%
data = pd.read_csv("./dataset/fetal_health.csv")
data.head()
# Out:
#    baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0           120.0          0.000             0.0                 0.000
# 1           132.0          0.006             0.0                 0.006
# 2           133.0          0.003             0.0                 0.008
# 3           134.0          0.003             0.0                 0.008
# 4           132.0          0.007             0.0                 0.008
#
#    light_decelerations  severe_decelerations  prolongued_decelerations  \
# 0                0.000                   0.0                       0.0
# 1                0.003                   0.0                       0.0
# 2                0.003                   0.0                       0.0
# 3                0.003                   0.0                       0.0
# 4                0.000                   0.0                       0.0
#
#    abnormal_short_term_variability  mean_value_of_short_term_variability  \
# ...

# %% [markdown]
# Data Analysis

# %%
corrmat= data.corr()
plt.figure(figsize=(15,15))  

cmap = sns.diverging_palette(220, 20, as_cmap=True)

sns.heatmap(corrmat,annot=True, cmap=cmap, center=0)

# %%
sns.countplot(data = data, x="fetal_health")

# %% [markdown]
# Data Scaling

# %%
X = data.iloc[:, :-1]
y = data['fetal_health']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# Model1: Logistic Regression

# %%
clf = LogisticRegression()

grid_values  = {'C' : [0.001, 0.01, 0.05, 0.1]}
# default metric to optimize over grid parameters: accuracy
grid_clf_acc = GridSearchCV(clf, param_grid = grid_values, cv = 5)
grid_clf_acc.fit(X_train, y_train)
y_decision_fn_scores_acc = grid_clf_acc.decision_function(X_test) 
print('Grid best parameter (max. accuracy): ', grid_clf_acc.best_params_)
print('Grid best score (accuracy): ', grid_clf_acc.best_score_)
# Out:
# Grid best parameter (max. accuracy):  {'C': 0.1}
# Grid best score (accuracy):  0.8917994260276139

# %% [markdown]
# Model2: SVC

# %%
clf = SVC(kernel='rbf')

grid_values = {'gamma': [0.001, 0.01, 0.05, 0.1, 1, 10, 100], 'C': [1, 10, 100, 1000]}
grid_clf_acc = GridSearchCV(clf, param_grid = grid_values, cv = 5)
grid_clf_acc.fit(X_train, y_train)
y_decision_fn_scores_acc = grid_clf_acc.decision_function(X_test) 

print('Grid best parameter (max. accuracy): ', grid_clf_acc.best_params_)
print('Grid best score (accuracy): ', grid_clf_acc.best_score_)
# Out:
# Grid best parameter (max. accuracy):  {'C': 100, 'gamma': 0.05}
# Grid best score (accuracy):  0.9247350462115562

# %% [markdown]
# Model3: Decision Tree

# %%
clf = DecisionTreeClassifier()

grid_values = {'max_depth': np.arange(3, 15),'criterion':['gini','entropy']}
grid_clf_acc = GridSearchCV(clf, param_grid = grid_values, cv = 5)
grid_clf_acc.fit(X_train, y_train)


print('Grid best parameter (max. accuracy): ', grid_clf_acc.best_params_)
DT_model = DecisionTreeClassifier(**grid_clf_acc.best_params_)
DT_model.fit(X_train, y_train)
pred = DT_model.predict(X_test)
accuracy = accuracy_score(y_test, pred)
print(accuracy)
# Out:
# Grid best parameter (max. accuracy):  {'criterion': 'entropy', 'max_depth': 12}
# 0.9153605015673981

# %% [markdown]
# Model4: RandomForest

# %%
clf = RandomForestClassifier()

grid_value = {
    'max_depth' : [4,6,8,10,12],
    'criterion' :['gini', 'entropy'],
    'n_jobs':[-1,1,None],
    'n_estimators': [100,150, 200,500,700,900],
    'max_features': ['auto', 'sqrt', 'log2']    
}

grid_clf_acc = GridSearchCV(clf, param_grid = grid_values, cv = 5)
grid_clf_acc.fit(X_train, y_train)
print('Grid best parameter (max. accuracy): ', grid_clf_acc.best_params_)
DT_model = RandomForestClassifier(**grid_clf_acc.best_params_)
DT_model.fit(X_train, y_train)
pred = DT_model.predict(X_test)
accuracy = accuracy_score(y_test, pred)
print(accuracy)
# Out:
# Grid best parameter (max. accuracy):  {'criterion': 'entropy', 'max_depth': 14}
# 0.9498432601880877
